# %% [markdown]
# <center>
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBMDeveloperSkillsNetwork-DS0105EN-SkillsNetwork/labs/Module2/images/SN_web_lightmode.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# **GORDON MOORE**<br>
# Engineering Manager

# %% [markdown]
# *I am interested in Data Science as this is a core capability for my role as Engineering Manager in Financial Services*

# %% [markdown]
# ### This code calculates the square of an input integer

# %%
valuey = int(input("Enter a Number: "));valuex=valuey**2;print(valuey," squared = ",valuex)
# Out:
# Enter a Number:  7
# 7  squared =  49

# %% [markdown]
# ***

# %% [markdown]
# - Main bullet point
#      - Sub bullet point
#      - Sub bullet point

# %% [markdown]
# <ol>
# <li>Input number to be squared</li>
# <li>Code calculates square of number</li>
# <li>Output square of number</li>
# </ol>

# %% [markdown]
# Code | Date | Team
# ----|---|---
# APIs | 03Nov21 | D
# Microservices | 28Feb22 | C
# Webhooks | 14Jun22 | A

# %% [markdown]
# <a href="https://www.coursera.org/" title="Coursera Main Page">Coursera Link</a>

# %% [markdown]
# Using Markdown
# ```Python
# str = "This is block level code"
# print(str)
# ```

# %% [markdown]
# ![Sparkle.JPEG](attachment:c0f02a8e-7c3b-4b1f-97a5-5aa154992e61.JPEG)

# %% [markdown]
# ~~These are earrings I made~~
